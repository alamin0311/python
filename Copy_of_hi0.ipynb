# %% [markdown]
# <a href="https://colab.research.google.com/github/alamin0311/python/blob/main/Copy_of_hi0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(1+3)
# Out:
# 4
